# %%
pip install tweety
# Out:
# ...
#      |████████████████████████████████| 911kB 2.8MB/s
# ...
#      |████████████████████████████████| 133kB 17.3MB/s
# ...
#   Created wheel for tweety: filename=tweety-0.1.6-cp36-none-any.whl size=4936 sha256=fcf3d9371985c6efb763590b135400b31b9d3e601a839ffb48129656c8e3ad5f
#   Stored in directory: /root/.cache/pip/wheels/78/07/1d/50c0a76e252a9abe27a09a10402dc922ecfae9eb52b63ec493
# ...
#   Created wheel for chromedriver-binary: filename=chromedriver_binary-74.0.3729.6.0-cp36-none-any.whl size=5072235 sha256=de1f28f6c042ed9edbc3c1be8e130043e3951d239c8619ad0d88513acabcc112
#   Stored in directory: /root/.cache/pip/wheels/ad/3c/cc/5ff90c249f4fdc6834632ca74e78647d870bb2e8444f9fe869
# Successfully built tweety chromedriver-binary
# ...

# %%
# tweepy 패키지 import

import tweepy
from tweepy import OAuthHandler, API
import pandas as pd

# API 인증요청

consumer_key = "vLw3mb7ORZNPSgvfHu5OMrWyJ"

consumer_secret = "0dAdeRI1OdpAUUHlQ6Lt9I69aafyBPpVgRDkpYDRZ3PnL2pCvJ"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)



# access 토큰 요청

access_token = "1255796435653517312-usn8fmL7FCau6L0CzE4mWTqtYsiVXi"

access_token_secret = "sNtJsiwuoUrU4e7SUDvqHRBQYFP0gUO64kBhbizAZbZgL"

auth.set_access_token(access_token, access_token_secret)



# twitter API 생성  

api = tweepy.API(auth)

# %%
keyword = input('키워드를 입력하세요: ')
max_tweets = 7000 # 최대 검색 트윗 수
searched_tweets = [] # 검색된 트위 저장
last_id = -1

while len(searched_tweets) < max_tweets:
    count = max_tweets - len(searched_tweets)
    try:
        new_tweets = api.search(q=keyword, count=count)
        if not new_tweets:
            break
        searched_tweets.extend(new_tweets)
        last_id = new_tweets[-1].id

    except tweepy.TweepError as e:
        break
# Out:
# 키워드를 입력하세요: 카카오

# %%
# 트윗에서 정보 추출

name = []
id = []
mention = []
date = []
time = []

for tweet in searched_tweets:
    created_time = str(tweet.created_at)
    time_split = created_time.split()

    name.append(tweet.user.name)
    id.append('@' + tweet.user.screen_name)
    mention.append(tweet.text)
    date.append(time_split[0])
    time.append(time_split[1])

# %%
data = {}
data['닉네임'] = name
data['ID'] = id
data['내용'] = mention
data['날짜'] = date
data['시간'] = time

# %%
# pandas로 데이터프레임 생성

df = pd.DataFrame(data)

# %%
df
# Out:
#                                           닉네임  ...        시간
# 0       5분 초고속 빠른입금 O1O-8885-0128 소소티켓 s5933F  ...  07:21:26
# 1                                         김생구  ...  07:21:24
# 2                                          지윤  ...  07:21:20
# 3                                         퍼피루  ...  07:21:15
# 4                                         마이열  ...  07:21:14
# ...                                       ...  ...       ...
# 6995                                      총총잉  ...  07:22:14
# 6996                               우리는 느리게 걷자  ...  07:22:06
# 6997  24시 빠른입금서비스 O1O-9585-0138 정상상품권 js2120F  ...  07:21:59
# 6998                                      하얀_  ...  07:21:57
# 6999                              [동솔존버] 구소니💜  ...  07:21:41
#
# [7000 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
df.to_csv('/gdrive/My Drive/카카오 트위터 크롤링.csv')

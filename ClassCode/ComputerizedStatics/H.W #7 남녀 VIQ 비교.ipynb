# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('/gdrive/My Drive/전산통계/원본 자료/data/brain_size.csv', sep = ';', na_values=".")
data.head()
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0           1  Female   133  132  124   118.0    64.5     816932
# 1           2    Male   140  150  124     NaN    72.5    1001121
# 2           3    Male   139  123  150   143.0    73.3    1038437
# 3           4    Male   133  129  128   172.0    68.8     965353
# 4           5  Female   137  132  134   147.0    65.0     951545

# %%
model = ols('VIQ ~  + Weight + Height + MRI_Count', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     3.366
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):             0.0297
# Time:                        14:53:17   Log-Likelihood:                -167.52
# No. Observations:                  38   AIC:                             343.0
# Df Residuals:                      34   BIC:                             349.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    113.6234     66.844      1.700      0.098     -22.220     249.466
# ...

# %%
estimate_viq = 113.6234 + (-0.0997 * data['Weight']) + (-2.2410 * data['Height']) + (0.0002 * data['MRI_Count'])
estimate_viq[:5] # 위의 결과에 따라 추정된 VIQ를 구함
# Out:
# 0    120.7007
# 1         NaN
# 2    142.7884
# 3    135.3648
# 4    143.6115
# dtype: float64

# %%
data['estimate_viq'] = estimate_viq

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  ...  Height  MRI_Count    mix_var  estimate_viq
# 0           1  Female   133  132  ...    64.5     816932  139.99605      120.7007
# 1           2    Male   140  150  ...    72.5    1001121        NaN           NaN
# 2           3    Male   139  123  ...    73.3    1038437  156.67299      142.7884
# 3           4    Male   133  129  ...    68.8     965353  150.21954      135.3648
# 4           5  Female   137  132  ...    65.0     951545  161.41350      143.6115
#
# [5 rows x 10 columns]

# %%
from scipy import stats

# %%
new_data = data[['Gender', 'estimate_viq']]
new_data.head()
# Out:
#    Gender  estimate_viq
# 0  Female      120.7007
# 1    Male           NaN
# 2    Male      142.7884
# 3    Male      135.3648
# 4  Female      143.6115

# %%
new_data_abs = new_data.dropna(axis = 0)
new_data_abs.head() # 결측값이 있는 행 제거
# Out:
#    Gender  estimate_viq
# 0  Female      120.7007
# 2    Male      142.7884
# 3    Male      135.3648
# 4  Female      143.6115
# 5  Female      130.1980

# %%
female_estimate_viq = new_data_abs[new_data_abs['Gender'] == 'Female']['estimate_viq']
male_estimate_viq = new_data_abs[new_data_abs['Gender'] == 'Male']['estimate_viq']
stats.ttest_ind(female_mix_var, male_mix_var)
# 추정된 VIQ가 성별에 따라 차이가 있는지 t-test로 검증
# Out:
# Ttest_indResult(statistic=0.21459754412568038, pvalue=0.8312921064841456)

# %% [markdown]
# #### 결과
#
# 뇌 크기, 키, 몸무게 차이를 배제하고 남자와 여자의 VIQ에는 차이가 없다고 할 수 있다.

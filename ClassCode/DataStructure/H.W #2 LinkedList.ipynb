# %% [markdown]
# ##Node 생성 class

# %%
class Node:

    def __init__(self, item = None, link = None):
        self.item = item
        self.link = link

# %% [markdown]
# ###Node Test

# %%
# test
a = Node("사과")
print(id(a))
print(a.item)
print(a.link)
# Out:
# 140425168452576
# 사과
# None

# %% [markdown]
# ##LinkedList 생성 class

# %%
class LinkedList:
    
    def __init__(self):
        self.root = None

    def append(self, item):
        newNode = Node(item)
        curNode = self.root
        if self.root == None:
            self.root = newNode
        else:
            while curNode.link != None:
                curNode = curNode.link
            curNode.link = newNode

    def insert(self, item, idx):
        newNode = Node(item)
        curNode = self.root
        if idx == 0:
            _tmp = self.root
            self.root = newNode
            newNode.link = _tmp
        else:
            for i in range(idx-1):
                curNode = curNode.link
            _tmp = curNode.link
            curNode.link = newNode
            newNode.link = _tmp

    def delete(self, item):
        preNode = curNode = self.root
        if curNode.item == item:
            self.root = curNode.link
        else:
            while curNode.link != None:
                preNode = curNode
                curNode = curNode.link
                if curNode.item == item:
                    preNode.link = curNode.link

    def find(self, item):
        curNode = self.root
        curIdx = 0
        if curNode.item == item:
            return curIdx
        else:
            while curNode.link != None:
                curNode = curNode.link
                curIdx += 1
                if curNode.item == item:
                    return curIdx
               

    def nodeFind(self, idx):
        if idx < 0 or idx > self.size():
            return None
        curNode = self.root
        if idx == 0:
            return self.root
        else:
            for i in range(idx):
                curNode = curNode.link
            return curNode

    def size(self):
        listSize = 1
        curNode = self.root
        while curNode.link != None:
            curNode = curNode.link
            listSize += 1
        return listSize

    def print(self):
        curNode = self.root
        print(curNode.item, end = ",")
        while curNode.link != None:
            curNode = curNode.link
            print(curNode.item, end = ",")
        print()

fruits = LinkedList()

fruits.append("apple")
fruits.append("cherry")
fruits.append("pear")
fruits.append("grape")

fruits.print()
# Out:
# apple,cherry,pear,grape,

# %% [markdown]
# ###LinkedList Test

# %%
fruits.size()
# Out:
# 4

# %%
fruits.nodeFind(3)

# %%
fruits.find('cherry')
# Out:
# 1

# %%
fruits.append("melon")
fruits.print()
# Out:
# apple,cherry,pear,grape,melon,

# %%
fruits.insert("banana", 2)
fruits.print()
# Out:
# apple,cherry,banana,pear,grape,melon,

# %%
fruits.delete("pear")
fruits.print()
# Out:
# apple,cherry,banana,grape,melon,

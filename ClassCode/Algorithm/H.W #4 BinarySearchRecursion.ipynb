# %%
class BS:
    def __init__(self, x):
        self.x = x

    def binarySearch(self):
        mini = 0
        maxi = 100
        print("%d를 %d번만에 찾았습니다." %(x, _binarySearch(x, mini, maxi))

    def _binarySearch(x, mini, maxi):
        mid = (mini + maxi) // 2
        
        if x == mid:
            return 0
        elif x > mid:
            mini = mid
            cnt = _binarySearch(x, mini, maxi)
        elif x < mid:
            maxi = mid
            cnt = _binarySearch(x, mini, maxi)
        cnt += 1
        return cnt

x = int(input("0~100 사이의 정수를 입력하세요 : "))
# Out:
#   File "<ipython-input-2-7da3436f9046>", line 7
#     def _binarySearch(x, mini, maxi):
#       ^
# SyntaxError: invalid syntax

# %%
def binarySearch(x, mini, maxi):
    mid = (mini + maxi) // 2
    # print(mini, mid, maxi)
    if x == mid:
        return 1
    elif x > mid:
        mini = mid
        cnt = binarySearch(x, mini, maxi)
    else:
        maxi = mid
        cnt = binarySearch(x, mini, maxi)
    cnt += 1
    return cnt

x = int(input("0~100 사이의 정수를 입력하세요 : "))
mini = 0
maxi = 100
print("%d를 %d번만에 찾았습니다." %(x, binarySearch(x, mini, maxi)))
# Out:
# 0~100 사이의 정수를 입력하세요 : 28
# 28를 5번만에 찾았습니다.
